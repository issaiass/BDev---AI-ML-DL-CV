# %% [markdown]
# # <font color="blue">Project 2: DoppelGanger Find your Celebrity Look-Alike </font>
# We have seen how face Recognition algorithms work. In short, they convert a face into a high dimensional vector and then learn a feature space in that high dimension. Once the algorithm learns a robust feature space, you can add more people to the same space and they will form a different cluster.
#
# ### <font color="green">Your Task</font>
# In this project, we will build a Fun Application - We will use the Face Embeddings to **find a doppelganger or look-alike to a given person.** Specifically, we will give you images of two persons and a celebrity dataset. Your task will be to find their celebrity look-alike. The first person is **Sofia Solares** who looks like the American Singer **Selena Gomez** and the second one is **Shashikant Pedwal** who looks like Indian Film Actor **Amitabh Bachchan**.
#
# Given below is the Expected Output.
#
# ### <font color="green">Expected Output</font>
#
# ![](https://www.learnopencv.com/wp-content/uploads/2020/05/doppelganger-output-selena.jpg)
#
# ![](https://www.learnopencv.com/wp-content/uploads/2020/05/doppelganger-output-amitabh.jpg)
#
#
# By now, you should be able to discern what the problem is, and how you are going to solve it. You simply need a dataset which has enough celebrity faces and use face embeddings to match the test image with the celebrity face embeddings. That's enough Hint!
#
# ## <font color="blue">The Dataset</font>
# There are many datasets which contain images of celebrities. Some of them are:
# * [CelebA Dataset](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html)
# * [VGGFace](https://www.robots.ox.ac.uk/~vgg/data/vgg_face/)
# * [VGGFace2](http://www.robots.ox.ac.uk/~vgg/data/vgg_face2/)
# * [MS-Celeb-1M](https://www.microsoft.com/en-us/research/project/ms-celeb-1m-challenge-recognizing-one-million-celebrities-real-world/)
# * [Celebrity-Together Dataset](https://www.robots.ox.ac.uk/~vgg/data/celebrity_together/)
#
# ### <font color="green">celeb_mini Dataset</font>
# Since most of the datasets are huge in size, we have curated a small dataset for this experiment.
#
# We will use a subset of the Query set of the Celebrity Together Dataset in this project. The query dataset has around 1100 celebs and is ~400MB in size.
#
# The subset we have created is using 5 images per celebrity and it has been saved in the **`../resource/asnlib/publicdata/celeb_mini`** folder. It is ~70MB in size. We have also provided a **`celeb_mapping.npy`** file which has the mapping of the code name to the actual name of the celebrity.
#
# The **`celeb_mini`** folder has the following structure:
#
# ```
# celeb_mini
# └───n00000001
# │   └──n00000001_00000263.JPEG
# │   └──n00000001_00000405.JPEG
# │      ...
# └───n00000003
# │   └──n00000003_00000386.JPEG
# │   └──n00000003_00000488.JPEG
# │       ...
# │
# ```
#
# **`celeb_mapping.npy`** contains a dictionary which contains the mapping between the folder names and the celebrity's actual name as show below:
# ```
# {'n00000001': 'A.J. Buckley',
#  'n00000002': 'A.R. Rahman',
#  'n00000003': 'Aamir Khan',
#  'n00000004': 'Aaron Staton',
#  'n00000005': 'Aaron Tveit',
#  'n00000006': 'Aaron Yoo',
#  'n00000007': 'Abbie Cornish',
#  .
#  .
#  .
# }
# ```
#
#
# ## <font color="blue">Marks Distribution </font>
# 1. **Implementation - 70 Marks**
# 1. **Video Explanation - 30 marks**
#
# #### <font color="red">Note that you are free to use any other dataset if you have the resources of space and compute to handle the large datasets.</font>

# %%
import os,random,glob
import dlib
import cv2
import numpy as np
import matplotlib.pyplot as plt
import time

import _pickle as cPickle # added pickle just for fun

# %matplotlib inline

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = (6.0,6.0)
matplotlib.rcParams['image.cmap'] = 'gray'
matplotlib.rcParams['image.interpolation'] = 'bilinear'

# %% [markdown]
# ## <font color="blue">Load the model for face landmarks and face recognition</font>

# %% [markdown]
# Initialize Dlib’s Face Detector, Facial Landmark Detector and Face Recognition neural network objects
#
# #### <font color="red">You are free to use other face recognition models as well. </font>

# %%
# Path to landmarks and face recognition model files
PREDICTOR_PATH = '../resource/lib/publicdata/models/shape_predictor_68_face_landmarks.dat'
FACE_RECOGNITION_MODEL_PATH = '../resource/lib/publicdata/models/dlib_face_recognition_resnet_model_v1.dat'

# Initialize face detector, facial landmarks detector 
# and face recognizer
faceDetector = dlib.get_frontal_face_detector()
shapePredictor = dlib.shape_predictor(PREDICTOR_PATH)
faceRecognizer = dlib.face_recognition_model_v1(FACE_RECOGNITION_MODEL_PATH)

# %% [markdown]
# ## <font color="blue">Explore Data </font>
# In this section, we provide sample code of how to load the images and use the label mapping for your reference. This should help you get started with handling images and finding the embeddings.

# %%
# Root folder of the dataset
faceDatasetFolder = '../resource/asnlib/publicdata/celeb_mini'
# Label -> Name Mapping file
labelMap = np.load("../resource/asnlib/publicdata/celeb_mapping.npy", allow_pickle=True).item()

# %%
# Each subfolder has images of a particular celeb
subfolders = os.listdir(faceDatasetFolder)

# Let us choose a random folder and display all images
random_folder = random.choice(subfolders)

# Also find out the name of the celeb from the folder name and folder-> name mapping dictionary loaded earlier
celebname = labelMap[random_folder]

# Load all images in the subfolder
imagefiles = os.listdir(os.path.join(faceDatasetFolder, random_folder))

# Read each image and display along with the filename and celeb name
for file in imagefiles:
#     Get full path of each image file
    fullPath = os.path.join(faceDatasetFolder,random_folder,file)
    im = cv2.imread(fullPath)
    plt.imshow(im[:,:,::-1])
    plt.show()
#     Also print the filename and celeb name
    print("File path = {}".format(fullPath))
    print("Celeb Name: {}".format(celebname))
# Out:
# File path = ../resource/asnlib/publicdata/celeb_mini/n00002550/n00002550_00000324.JPEG
# Celeb Name: Walton Goggins
# File path = ../resource/asnlib/publicdata/celeb_mini/n00002550/n00002550_00000169.JPEG
# Celeb Name: Walton Goggins
# File path = ../resource/asnlib/publicdata/celeb_mini/n00002550/n00002550_00000305.JPEG
# Celeb Name: Walton Goggins
# File path = ../resource/asnlib/publicdata/celeb_mini/n00002550/n00002550_00000515.JPEG
# Celeb Name: Walton Goggins
# File path = ../resource/asnlib/publicdata/celeb_mini/n00002550/n00002550_00000125.JPEG
# Celeb Name: Walton Goggins

# %% [markdown]
# ## <font color="blue">TODO</font>
# You have to write the code for enrollment and testing to get the desired output as shown in the intro section.
#
# **You can take help from the code we had provided in week 4 material.**

# %% [markdown]
# ## <font color="red">1. Enrollment of Celeb Images </font>
# Process images one by and one.
#
# Convert image from RGB to BGR, because Dlib uses RGB as default format.
#
# Detect faces in the image and compute a face descriptor for each image and save them in an array so that it can be used during testing.

# %%
#YOUR CODE HERE

# read subfolders in folder "faceDatasetFolder"
subfolders = []
for x in os.listdir(faceDatasetFolder):
  xpath = os.path.join(faceDatasetFolder, x)
  if os.path.isdir(xpath):
    subfolders.append(xpath)

# fileLabelMap is dict with keys the full path of the file
# and values is the subfolder associated
fileLabelMap = {}
imagePaths = []
for i, subfolder in enumerate(subfolders):
  for x in os.listdir(subfolder):
    xpath = os.path.join(subfolder, x)
    if x.endswith('JPEG'):
      imagePaths.append(xpath)
      fileLabelMap[xpath] = subfolder.split('/')[-1]

        
# Process images one by one
# We will store face descriptors in an ndarray (faceDescriptors)
# and their corresponding labels in dictionary (index)
index = {}
i = 0
faceDescriptors = None
for imagePath in imagePaths:
  print("processing: {}".format(imagePath))
  # read image and convert it to RGB
  img = cv2.imread(imagePath)
  imgDlib = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

  # detect faces in image
  face = faceDetector(imgDlib)

  # go to the next image if a face is not found
  if not len(face):
    continue

  # Find facial landmarks for each detected face
  shape = shapePredictor(imgDlib, face[0])

  # Compute face descriptor using neural network defined in Dlib.
  # It is a 128D vector that describes the face in img identified by shape.
  faceDescriptor = faceRecognizer.compute_face_descriptor(img, shape)

  # Convert face descriptor from Dlib's format to list, then a NumPy array
  faceDescriptorList = [x for x in faceDescriptor]
  faceDescriptorNdarray = np.asarray(faceDescriptorList, dtype=np.float64)
  faceDescriptorNdarray = faceDescriptorNdarray[np.newaxis, :]

  # Stack face descriptors (1x128) for each face in images, as rows
  if faceDescriptors is None:
    faceDescriptors = faceDescriptorNdarray
  else:
    faceDescriptors = np.concatenate((faceDescriptors, faceDescriptorNdarray), axis=0)

  # save the label for this face in index. We will use it later to identify
  # person name corresponding to face descriptors stored in NumPy Array
  index[i] = fileLabelMap[imagePath]
  i += 1
# Out:
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001267/n00001267_00000198.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001267/n00001267_00000045.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001267/n00001267_00000643.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001267/n00001267_00000205.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001267/n00001267_00000638.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000111/n00000111_00000033.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000111/n00000111_00000770.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000111/n00000111_00000459.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000111/n00000111_00000602.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000111/n00000111_00000194.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000085/n00000085_00000107.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000085/n00000085_00000413.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000085/n00000085_00000557.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000085/n00000085_00000127.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000085/n00000085_00000074.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002092/n00002092_00000359.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002092/n00002092_00000397.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002092/n00002092_00000621.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002092/n00002092_00000694.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002092/n00002092_00000509.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001033/n00001033_00000579.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001033/n00001033_00000867.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001033/n00001033_00000294.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001033/n00001033_00000806.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001033/n00001033_00000688.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001484/n00001484_00000608.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001484/n00001484_00000096.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001484/n00001484_00000235.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001484/n00001484_00000448.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001484/n00001484_00000452.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001124/n00001124_00000991.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001124/n00001124_00000088.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001124/n00001124_00000856.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001124/n00001124_00000552.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001124/n00001124_00000397.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000731/n00000731_00000049.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000731/n00000731_00000100.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000731/n00000731_00000053.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000731/n00000731_00000356.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000731/n00000731_00000244.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000156/n00000156_00000096.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000156/n00000156_00000014.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000156/n00000156_00000464.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000156/n00000156_00000429.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000156/n00000156_00000645.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000166/n00000166_00000028.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000166/n00000166_00000454.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000166/n00000166_00000788.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000166/n00000166_00000360.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000166/n00000166_00000638.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000411/n00000411_00000047.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000411/n00000411_00000010.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000411/n00000411_00000677.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000411/n00000411_00000421.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000411/n00000411_00000494.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000214/n00000214_00000795.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000214/n00000214_00000255.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000214/n00000214_00000432.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000214/n00000214_00000214.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000214/n00000214_00000384.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002419/n00002419_00000343.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002419/n00002419_00000586.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002419/n00002419_00000709.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002419/n00002419_00000713.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002419/n00002419_00000640.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001153/n00001153_00000270.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001153/n00001153_00000284.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001153/n00001153_00000314.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001153/n00001153_00000745.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001153/n00001153_00000293.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002129/n00002129_00000254.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002129/n00002129_00000491.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002129/n00002129_00000106.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002129/n00002129_00000147.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002129/n00002129_00000074.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001209/n00001209_00000239.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001209/n00001209_00000517.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001209/n00001209_00000429.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001209/n00001209_00000130.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001209/n00001209_00000487.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001219/n00001219_00000075.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001219/n00001219_00000192.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001219/n00001219_00000540.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001219/n00001219_00000388.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001219/n00001219_00000002.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001799/n00001799_00000850.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001799/n00001799_00000145.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001799/n00001799_00000606.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001799/n00001799_00000190.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001799/n00001799_00000391.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002514/n00002514_00000483.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002514/n00002514_00000790.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002514/n00002514_00000051.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002514/n00002514_00000293.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002514/n00002514_00000600.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000353/n00000353_00000613.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000353/n00000353_00000687.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000353/n00000353_00000280.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000353/n00000353_00000516.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000353/n00000353_00000453.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000230/n00000230_00000356.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000230/n00000230_00000458.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000230/n00000230_00000638.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000230/n00000230_00000205.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000230/n00000230_00000614.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000980/n00000980_00000134.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000980/n00000980_00000363.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000980/n00000980_00000724.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000980/n00000980_00000621.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000980/n00000980_00000379.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000265/n00000265_00000348.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000265/n00000265_00000164.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000265/n00000265_00000094.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000265/n00000265_00000344.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000265/n00000265_00000466.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000152/n00000152_00000219.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000152/n00000152_00000433.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000152/n00000152_00000540.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000152/n00000152_00000350.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000152/n00000152_00000262.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002423/n00002423_00000885.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002423/n00002423_00000050.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002423/n00002423_00000181.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002423/n00002423_00000928.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002423/n00002423_00000115.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001425/n00001425_00000342.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001425/n00001425_00000732.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001425/n00001425_00000122.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001425/n00001425_00000378.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001425/n00001425_00000749.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000496/n00000496_00000857.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000496/n00000496_00000197.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000496/n00000496_00000549.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000496/n00000496_00000103.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000496/n00000496_00000949.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000895/n00000895_00000652.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000895/n00000895_00000238.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000895/n00000895_00000107.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000895/n00000895_00000392.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000895/n00000895_00000886.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000477/n00000477_00000622.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000477/n00000477_00000878.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000477/n00000477_00000137.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000477/n00000477_00000863.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000477/n00000477_00000068.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000365/n00000365_00000733.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000365/n00000365_00000210.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000365/n00000365_00000695.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000365/n00000365_00000174.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000365/n00000365_00000498.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001034/n00001034_00000796.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001034/n00001034_00000942.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001034/n00001034_00000755.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001034/n00001034_00000523.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001034/n00001034_00000466.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001436/n00001436_00000684.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001436/n00001436_00000407.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001436/n00001436_00000396.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001436/n00001436_00000925.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001436/n00001436_00000508.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002270/n00002270_00000139.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002270/n00002270_00000247.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002270/n00002270_00000289.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002270/n00002270_00000178.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002270/n00002270_00000883.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002507/n00002507_00000524.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002507/n00002507_00000226.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002507/n00002507_00000495.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002507/n00002507_00000724.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002507/n00002507_00000949.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000235/n00000235_00000948.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000235/n00000235_00000380.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000235/n00000235_00000142.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000235/n00000235_00000210.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000235/n00000235_00000358.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000360/n00000360_00000069.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000360/n00000360_00000399.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000360/n00000360_00000966.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000360/n00000360_00000639.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000360/n00000360_00000194.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000193/n00000193_00000334.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000193/n00000193_00000836.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000193/n00000193_00000046.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000193/n00000193_00000122.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000193/n00000193_00000178.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002424/n00002424_00000773.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002424/n00002424_00000617.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002424/n00002424_00000744.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002424/n00002424_00000292.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002424/n00002424_00000175.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002399/n00002399_00000732.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002399/n00002399_00000292.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002399/n00002399_00000909.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002399/n00002399_00000525.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002399/n00002399_00000641.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000138/n00000138_00000726.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000138/n00000138_00000268.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000138/n00000138_00000570.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000138/n00000138_00000069.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000138/n00000138_00000839.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001083/n00001083_00000115.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001083/n00001083_00000400.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001083/n00001083_00000375.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001083/n00001083_00000123.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001083/n00001083_00000284.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001814/n00001814_00000026.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001814/n00001814_00000375.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001814/n00001814_00000876.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001814/n00001814_00000620.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001814/n00001814_00000660.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002520/n00002520_00000754.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002520/n00002520_00000299.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002520/n00002520_00000104.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002520/n00002520_00000689.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002520/n00002520_00000098.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000871/n00000871_00000258.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000871/n00000871_00000055.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000871/n00000871_00000700.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000871/n00000871_00000080.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000871/n00000871_00000576.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000700/n00000700_00000236.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000700/n00000700_00000954.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000700/n00000700_00000057.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000700/n00000700_00000283.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000700/n00000700_00000660.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001656/n00001656_00000414.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001656/n00001656_00000619.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001656/n00001656_00000662.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001656/n00001656_00000635.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001656/n00001656_00000603.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001038/n00001038_00000228.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001038/n00001038_00000971.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001038/n00001038_00000253.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001038/n00001038_00000009.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001038/n00001038_00000269.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000669/n00000669_00000671.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000669/n00000669_00000095.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000669/n00000669_00000543.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000669/n00000669_00000831.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000669/n00000669_00000689.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001636/n00001636_00000156.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001636/n00001636_00000835.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001636/n00001636_00000091.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001636/n00001636_00000592.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001636/n00001636_00000843.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001809/n00001809_00000703.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001809/n00001809_00000719.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001809/n00001809_00000152.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001809/n00001809_00000471.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001809/n00001809_00000298.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000533/n00000533_00000208.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000533/n00000533_00000286.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000533/n00000533_00000117.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000533/n00000533_00000269.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000533/n00000533_00000199.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001377/n00001377_00000901.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001377/n00001377_00000612.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001377/n00001377_00000452.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001377/n00001377_00000385.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001377/n00001377_00000540.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000509/n00000509_00000475.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000509/n00000509_00000377.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000509/n00000509_00000639.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000509/n00000509_00000004.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000509/n00000509_00000101.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000780/n00000780_00000884.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000780/n00000780_00000282.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000780/n00000780_00000312.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000780/n00000780_00000040.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000780/n00000780_00000113.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000038/n00000038_00000594.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000038/n00000038_00000003.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000038/n00000038_00000347.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000038/n00000038_00000438.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000038/n00000038_00000757.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000220/n00000220_00000232.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000220/n00000220_00000265.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000220/n00000220_00000320.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000220/n00000220_00000199.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000220/n00000220_00000228.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000003/n00000003_00000386.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000003/n00000003_00000488.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000003/n00000003_00000514.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000003/n00000003_00000922.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000003/n00000003_00000670.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000831/n00000831_00000418.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000831/n00000831_00000156.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000831/n00000831_00000337.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000831/n00000831_00000064.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000831/n00000831_00000204.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000488/n00000488_00000125.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000488/n00000488_00000647.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000488/n00000488_00000373.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000488/n00000488_00000190.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000488/n00000488_00000061.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001756/n00001756_00000798.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001756/n00001756_00000022.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001756/n00001756_00000673.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001756/n00001756_00000054.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001756/n00001756_00000346.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001747/n00001747_00000387.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001747/n00001747_00000348.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001747/n00001747_00000607.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001747/n00001747_00000333.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001747/n00001747_00000313.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000531/n00000531_00000986.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000531/n00000531_00000591.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000531/n00000531_00000461.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000531/n00000531_00000103.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000531/n00000531_00000178.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000203/n00000203_00000824.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000203/n00000203_00000131.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000203/n00000203_00000613.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000203/n00000203_00000737.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000203/n00000203_00000424.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001348/n00001348_00000831.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001348/n00001348_00000313.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001348/n00001348_00000688.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001348/n00001348_00000597.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001348/n00001348_00000763.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000376/n00000376_00000271.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000376/n00000376_00000284.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000376/n00000376_00000210.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000376/n00000376_00000573.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000376/n00000376_00000476.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000641/n00000641_00000994.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000641/n00000641_00000941.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000641/n00000641_00000428.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000641/n00000641_00000110.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000641/n00000641_00000594.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001103/n00001103_00000974.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001103/n00001103_00000519.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001103/n00001103_00000387.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001103/n00001103_00000493.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001103/n00001103_00000555.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000611/n00000611_00000858.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000611/n00000611_00000442.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000611/n00000611_00000025.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000611/n00000611_00000947.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000611/n00000611_00000028.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001769/n00001769_00000850.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001769/n00001769_00000240.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001769/n00001769_00000095.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001769/n00001769_00000574.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001769/n00001769_00000610.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000475/n00000475_00000421.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000475/n00000475_00000725.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000475/n00000475_00000071.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000475/n00000475_00000118.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000475/n00000475_00000026.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001796/n00001796_00000073.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001796/n00001796_00000507.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001796/n00001796_00000638.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001796/n00001796_00000803.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001796/n00001796_00000177.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000173/n00000173_00000499.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000173/n00000173_00000601.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000173/n00000173_00000378.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000173/n00000173_00000587.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000173/n00000173_00000381.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001512/n00001512_00000270.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001512/n00001512_00000175.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001512/n00001512_00000773.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001512/n00001512_00000285.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001512/n00001512_00000483.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001248/n00001248_00000070.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001248/n00001248_00000695.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001248/n00001248_00000441.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001248/n00001248_00000725.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001248/n00001248_00000089.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002434/n00002434_00000206.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002434/n00002434_00000416.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002434/n00002434_00000908.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002434/n00002434_00000904.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002434/n00002434_00000293.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000145/n00000145_00000864.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000145/n00000145_00000022.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000145/n00000145_00000130.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000145/n00000145_00000556.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000145/n00000145_00000624.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000990/n00000990_00000965.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000990/n00000990_00000251.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000990/n00000990_00000898.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000990/n00000990_00000590.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000990/n00000990_00000031.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001241/n00001241_00000020.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001241/n00001241_00000125.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001241/n00001241_00000328.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001241/n00001241_00000693.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001241/n00001241_00000519.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000944/n00000944_00000276.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000944/n00000944_00000515.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000944/n00000944_00000128.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000944/n00000944_00000889.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000944/n00000944_00000919.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002525/n00002525_00000219.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002525/n00002525_00000111.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002525/n00002525_00000664.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002525/n00002525_00000255.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002525/n00002525_00000852.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002368/n00002368_00000101.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002368/n00002368_00000265.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002368/n00002368_00000818.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002368/n00002368_00000475.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002368/n00002368_00000195.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001646/n00001646_00000784.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001646/n00001646_00000004.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001646/n00001646_00000268.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001646/n00001646_00000198.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001646/n00001646_00000546.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001320/n00001320_00000710.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001320/n00001320_00000531.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001320/n00001320_00000459.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001320/n00001320_00000012.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001320/n00001320_00000161.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002472/n00002472_00000419.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002472/n00002472_00000690.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002472/n00002472_00000633.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002472/n00002472_00000078.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002472/n00002472_00000956.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000104/n00000104_00000007.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000104/n00000104_00000343.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000104/n00000104_00000841.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000104/n00000104_00000744.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000104/n00000104_00000139.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001637/n00001637_00000973.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001637/n00001637_00000640.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001637/n00001637_00000247.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001637/n00001637_00000787.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001637/n00001637_00000070.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001767/n00001767_00000929.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001767/n00001767_00000363.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001767/n00001767_00000175.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001767/n00001767_00000513.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001767/n00001767_00000339.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001632/n00001632_00000291.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001632/n00001632_00000418.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001632/n00001632_00000136.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001632/n00001632_00000013.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001632/n00001632_00000788.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000624/n00000624_00000304.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000624/n00000624_00000426.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000624/n00000624_00000902.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000624/n00000624_00000332.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000624/n00000624_00000538.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001883/n00001883_00000786.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001883/n00001883_00000342.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001883/n00001883_00000143.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001883/n00001883_00000159.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001883/n00001883_00000461.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000992/n00000992_00000571.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000992/n00000992_00000052.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000992/n00000992_00000357.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000992/n00000992_00000727.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000992/n00000992_00000195.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002394/n00002394_00000597.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002394/n00002394_00000684.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002394/n00002394_00000651.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002394/n00002394_00000057.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002394/n00002394_00000221.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001336/n00001336_00000135.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001336/n00001336_00000772.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001336/n00001336_00000508.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001336/n00001336_00000174.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001336/n00001336_00000949.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001143/n00001143_00000378.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001143/n00001143_00000143.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001143/n00001143_00000374.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001143/n00001143_00000417.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001143/n00001143_00000620.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000359/n00000359_00000403.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000359/n00000359_00000854.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000359/n00000359_00000838.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000359/n00000359_00000225.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000359/n00000359_00000707.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001066/n00001066_00000091.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001066/n00001066_00000287.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001066/n00001066_00000402.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001066/n00001066_00000815.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001066/n00001066_00000480.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000012/n00000012_00000243.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000012/n00000012_00000594.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000012/n00000012_00000982.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000012/n00000012_00000242.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000012/n00000012_00000865.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000839/n00000839_00000514.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000839/n00000839_00000689.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000839/n00000839_00000017.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000839/n00000839_00000172.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000839/n00000839_00000575.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000640/n00000640_00000256.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000640/n00000640_00000671.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000640/n00000640_00000667.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000640/n00000640_00000407.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000640/n00000640_00000610.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002370/n00002370_00000543.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002370/n00002370_00000903.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002370/n00002370_00000488.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002370/n00002370_00000555.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002370/n00002370_00000563.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001107/n00001107_00000743.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001107/n00001107_00000484.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001107/n00001107_00000538.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001107/n00001107_00000939.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001107/n00001107_00000112.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001739/n00001739_00000791.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001739/n00001739_00000712.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001739/n00001739_00000288.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001739/n00001739_00000303.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001739/n00001739_00000159.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000045/n00000045_00000789.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000045/n00000045_00000707.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000045/n00000045_00000422.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000045/n00000045_00000269.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000045/n00000045_00000584.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002336/n00002336_00000248.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002336/n00002336_00000662.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002336/n00002336_00000382.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002336/n00002336_00000101.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002336/n00002336_00000121.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002465/n00002465_00000192.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002465/n00002465_00000262.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002465/n00002465_00000171.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002465/n00002465_00000577.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002465/n00002465_00000331.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001028/n00001028_00000233.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001028/n00001028_00000205.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001028/n00001028_00000356.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001028/n00001028_00000209.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001028/n00001028_00000746.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002479/n00002479_00000354.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002479/n00002479_00000339.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002479/n00002479_00000509.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002479/n00002479_00000246.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002479/n00002479_00000568.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000747/n00000747_00000929.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000747/n00000747_00000319.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000747/n00000747_00000250.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000747/n00000747_00000397.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000747/n00000747_00000051.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002401/n00002401_00000074.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002401/n00002401_00000151.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002401/n00002401_00000219.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002401/n00002401_00000673.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002401/n00002401_00000536.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000607/n00000607_00000085.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000607/n00000607_00000744.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000607/n00000607_00000764.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000607/n00000607_00000553.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000607/n00000607_00000178.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001612/n00001612_00000453.JPEG
# ...
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001161/n00001161_00000275.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001161/n00001161_00000500.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001161/n00001161_00000605.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000378/n00000378_00000149.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000378/n00000378_00000036.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000378/n00000378_00000466.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000378/n00000378_00000145.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000378/n00000378_00000329.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000074/n00000074_00000579.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000074/n00000074_00000056.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000074/n00000074_00000344.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000074/n00000074_00000446.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000074/n00000074_00000114.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001024/n00001024_00000109.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001024/n00001024_00000353.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001024/n00001024_00000312.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001024/n00001024_00000580.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001024/n00001024_00000646.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000890/n00000890_00000016.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000890/n00000890_00000378.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000890/n00000890_00000365.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000890/n00000890_00000313.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000890/n00000890_00000518.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002237/n00002237_00000934.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002237/n00002237_00000152.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002237/n00002237_00000778.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002237/n00002237_00000447.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002237/n00002237_00000095.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001967/n00001967_00000493.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001967/n00001967_00000364.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001967/n00001967_00000295.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001967/n00001967_00000755.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001967/n00001967_00000718.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000779/n00000779_00000912.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000779/n00000779_00000400.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000779/n00000779_00000820.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000779/n00000779_00000267.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000779/n00000779_00000011.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001672/n00001672_00000628.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001672/n00001672_00000486.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001672/n00001672_00000813.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001672/n00001672_00000034.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001672/n00001672_00000864.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001678/n00001678_00000048.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001678/n00001678_00000710.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001678/n00001678_00000679.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001678/n00001678_00000585.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001678/n00001678_00000815.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002049/n00002049_00000272.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002049/n00002049_00000643.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002049/n00002049_00000423.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002049/n00002049_00000679.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002049/n00002049_00000454.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000672/n00000672_00000252.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000672/n00000672_00000593.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000672/n00000672_00000570.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000672/n00000672_00000403.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000672/n00000672_00000090.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000556/n00000556_00000250.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000556/n00000556_00000591.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000556/n00000556_00000564.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000556/n00000556_00000155.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000556/n00000556_00000270.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000449/n00000449_00000730.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000449/n00000449_00000161.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000449/n00000449_00000751.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000449/n00000449_00000593.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000449/n00000449_00000454.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001898/n00001898_00000275.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001898/n00001898_00000648.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001898/n00001898_00000853.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001898/n00001898_00000366.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001898/n00001898_00000367.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000091/n00000091_00000306.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000091/n00000091_00000868.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000091/n00000091_00000409.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000091/n00000091_00000491.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000091/n00000091_00000448.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000906/n00000906_00000177.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000906/n00000906_00000649.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000906/n00000906_00000398.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000906/n00000906_00000478.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000906/n00000906_00000064.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000862/n00000862_00000385.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000862/n00000862_00000653.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000862/n00000862_00000487.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000862/n00000862_00000167.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000862/n00000862_00000757.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000590/n00000590_00000058.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000590/n00000590_00000038.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000590/n00000590_00000014.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000590/n00000590_00000388.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000590/n00000590_00000887.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000625/n00000625_00000465.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000625/n00000625_00000263.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000625/n00000625_00000130.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000625/n00000625_00000413.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000625/n00000625_00000937.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001297/n00001297_00000589.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001297/n00001297_00000479.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001297/n00001297_00000480.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001297/n00001297_00000395.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001297/n00001297_00000213.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002615/n00002615_00000216.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002615/n00002615_00000144.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002615/n00002615_00000738.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002615/n00002615_00000020.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002615/n00002615_00000651.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002285/n00002285_00000793.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002285/n00002285_00000697.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002285/n00002285_00000137.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002285/n00002285_00000100.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002285/n00002285_00000291.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002214/n00002214_00000857.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002214/n00002214_00000355.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002214/n00002214_00000748.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002214/n00002214_00000142.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002214/n00002214_00000093.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001296/n00001296_00000007.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001296/n00001296_00000292.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001296/n00001296_00000705.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001296/n00001296_00000288.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001296/n00001296_00000162.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000519/n00000519_00000086.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000519/n00000519_00000069.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000519/n00000519_00000793.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000519/n00000519_00000360.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000519/n00000519_00000414.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000324/n00000324_00000242.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000324/n00000324_00000716.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000324/n00000324_00000326.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000324/n00000324_00000388.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000324/n00000324_00000556.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000532/n00000532_00000230.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000532/n00000532_00000617.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000532/n00000532_00000335.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000532/n00000532_00000928.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000532/n00000532_00000289.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001008/n00001008_00000019.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001008/n00001008_00000404.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001008/n00001008_00000003.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001008/n00001008_00000263.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001008/n00001008_00000074.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000289/n00000289_00000911.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000289/n00000289_00000069.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000289/n00000289_00000321.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000289/n00000289_00000462.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000289/n00000289_00000602.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001734/n00001734_00000919.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001734/n00001734_00000037.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001734/n00001734_00000083.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001734/n00001734_00000739.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001734/n00001734_00000353.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001232/n00001232_00000133.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001232/n00001232_00000305.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001232/n00001232_00000294.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001232/n00001232_00000938.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001232/n00001232_00000610.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000056/n00000056_00000434.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000056/n00000056_00000394.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000056/n00000056_00000208.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000056/n00000056_00000619.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000056/n00000056_00000336.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000059/n00000059_00000172.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000059/n00000059_00000431.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000059/n00000059_00000057.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000059/n00000059_00000914.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000059/n00000059_00000216.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000950/n00000950_00000607.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000950/n00000950_00000781.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000950/n00000950_00000884.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000950/n00000950_00000892.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00000950/n00000950_00000579.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002148/n00002148_00000372.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002148/n00002148_00000247.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002148/n00002148_00000523.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002148/n00002148_00000446.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00002148/n00002148_00000484.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001166/n00001166_00000366.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001166/n00001166_00000385.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001166/n00001166_00000188.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001166/n00001166_00000472.JPEG
# processing: ../resource/asnlib/publicdata/celeb_mini/n00001166/n00001166_00000346.JPEG

# %% [markdown]
# ## <font color="red">2. Testing</font>
# Once you have enrolled the celebs, you should be able to use them to find the closest celeb to the given test image using minimum distance rule.
#
# You need to find the embeddings of the test images and compare it with the enrolled celebs to find the look-alike.
#
# Finally, display the celeb along side the input image. Partial code is given.

# %%
matplotlib.rcParams['figure.figsize'] = (12.0,12.0)

# %%
# Write descriors and index to disk
np.save('descriptors.npy', faceDescriptors)
# index has image paths in same order as descriptors in faceDescriptors
with open('index.pkl', 'wb') as f:
  cPickle.dump(index, f)

# load descriptors and index file generated during enrollment
index = np.load('index.pkl', allow_pickle=True)
faceDescriptorsEnrolled = np.load('descriptors.npy')


# theshold for the detection of the celebrities
THRESHOLD = 0.7

# find the celeb image given the map and the label
def findCeleb(fileLabelMap, label):
    for key in fileLabelMap:
      if fileLabelMap[key] == label:
        celeb_a_like_path = os.path.join(faceDatasetFolder, label)
        celeb_a_like_pict = sorted(os.listdir(celeb_a_like_path))[0]
        celeb_a_like_full_path = os.path.join(celeb_a_like_path, celeb_a_like_pict)
        break
    return cv2.imread(celeb_a_like_full_path)

# read image
testImages = glob.glob('../resource/asnlib/publicdata/test-images/*.jpg')

for test in testImages:
    im = cv2.imread(test)
    imDlib = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
    
    #####################
    #  YOUR CODE HERE
    
    # detect faces in image
    face = faceDetector(cv2.cvtColor(im, cv2.COLOR_BGR2RGB))

    # Find facial landmarks for the detected face
    shape = shapePredictor(cv2.cvtColor(im, cv2.COLOR_BGR2RGB), face[0])

    # Compute face descriptor using neural network defined in Dlib
    # using facial landmark shape
    faceDescriptor = faceRecognizer.compute_face_descriptor(im, shape)

    # Convert face descriptor from Dlib's format to list, then a NumPy array
    faceDescriptorList = [m for m in faceDescriptor]
    faceDescriptorNdarray = np.asarray(faceDescriptorList, dtype=np.float64)
    faceDescriptorNdarray = faceDescriptorNdarray[np.newaxis, :]

    # Calculate Euclidean distances between face descriptor calculated on face dectected
    # in current frame with all the face descriptors we calculated while enrolling faces
    distances = np.linalg.norm(faceDescriptorsEnrolled - faceDescriptorNdarray, axis=1)
    # Calculate minimum distance and index of this face
    argmin = np.argmin(distances)  # index
    minDistance = distances[argmin]  # minimum distance

    # Dlib specifies that in general, if two face descriptor vectors have a Euclidean
    # distance between them less than 0.6 then they are from the same
    # person, otherwise they are from different people.

    # This threshold will vary depending upon number of images enrolled
    # and various variations (illuminaton, camera quality) between
    # enrolled images and query image
    # We are using a threshold of 0.5

    # If minimum distance if less than threshold
    # find the name of person from index
    # else the person in query image is unknown
    if minDistance <= THRESHOLD:
      label = index[argmin]
    else:
      label = 'unknown'

    celeb_name = labelMap[label]

    ####################
    
    plt.subplot(121)
    plt.imshow(imDlib)
    plt.title("test img")
    
    #TODO - display celeb image which looks like the test image instead of the black image. 
    plt.subplot(122)

    celeb_a_like = findCeleb(fileLabelMap, label)
      
    plt.imshow(celeb_a_like[:,:,::-1])
    plt.title("Celeb Look-Alike={}".format(celeb_name))
    plt.show()
